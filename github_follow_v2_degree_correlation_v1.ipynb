# %%
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
import operator
from infomap import infomap
from pymongo import MongoClient
from matplotlib.colors import LogNorm
from matplotlib.gridspec import GridSpec
# %matplotlib inline

# %% [markdown]
# Reading the the follow graph.

# %%
filename = "/Users/arefindk/Desktop/github_merged_pull/trimmed_follow_users_strong_int.graphml"
G  = nx.read_graphml(filename)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-2-676a55e80bc8> in <module>()
#       1 filename = "/Users/arefindk/Desktop/github_merged_pull/trimmed_follow_users_strong_int.graphml"
# ----> 2 G  = nx.read_graphml(filename)
#
# <decorator-gen-327> in read_graphml(path, node_type)
#
# //anaconda/lib/python2.7/site-packages/networkx/utils/decorators.pyc in _open_file(func, *args, **kwargs)
#     196         if is_string_like(path):
#     197             ext = splitext(path)[1]
# --> 198             fobj = _dispatch_dict[ext](path, mode=mode)
#     199             close_fobj = True
#     200         elif hasattr(path, 'read'):
#
# IOError: [Errno 2] No such file or directory: '/Users/arefindk/Desktop/github_merged_pull/trimmed_follow_users_strong_int.graphml'

# %%
##create matrix for graph G
##each entry is correlation between i and j
e_ij = nx.degree_mixing_matrix(G,x='in',y='in')
r = nx.degree_pearson_correlation_coefficient(G,x='in',y='in')
##visualize matrix
fig = plt.figure(figsize=(16,10))
plt.title(r"Degree Correlation Matrix of follow network (in-in), $r$="+str(r),fontsize=14)
plt.pcolormesh(e_ij, norm=LogNorm(vmax=e_ij.max()),cmap='plasma')
plt.colorbar()
plt.show()

# %%
##each entry is correlation between i and j
e_ij = nx.degree_mixing_matrix(G,x='in',y='out')
r = nx.degree_pearson_correlation_coefficient(G,x='in',y='out')
##visualize matrix
fig = plt.figure(figsize=(16,10))
plt.title(r"Degree Correlation Matrix of follow network (in-out), $r$="+str(r),fontsize=14)
plt.pcolormesh(e_ij, norm=LogNorm(vmax=e_ij.max()),cmap='plasma')
plt.colorbar()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-5e144e956bd0> in <module>()
#       1 ##each entry is correlation between i and j
# ----> 2 e_ij = nx.degree_mixing_matrix(G,x='in',y='out')
#       3 r = nx.degree_pearson_correlation_coefficient(G,x='in',y='out')
#       4 ##visualize matrix
#       5 fig = plt.figure(figsize=(16,10))
#
# //anaconda/lib/python2.7/site-packages/networkx/algorithms/assortativity/mixing.pyc in degree_mixing_matrix(G, x, y, weight, nodes, normalized)
#     159     m=max(s)
#     160     mapping=dict(zip(range(m+1),range(m+1)))
# --> 161     a=dict_to_numpy_array(d,mapping=mapping)
#     162     if normalized:
#     163         a=a/a.sum()
#
# //anaconda/lib/python2.7/site-packages/networkx/utils/misc.pyc in dict_to_numpy_array(d, mapping)
#     134     with optional mapping."""
#     135     try:
# --> 136         return dict_to_numpy_array2(d, mapping)
#     137     except (AttributeError, TypeError):
#     138         # AttributeError is when no mapping was provided and v.keys() fails.
#
# //anaconda/lib/python2.7/site-packages/networkx/utils/misc.pyc in dict_to_numpy_array2(d, mapping)
#     154     a = numpy.zeros((n, n))
#     155     for k1, i in mapping.items():
# --> 156         for k2, j in mapping.items():
#     157             try:
#     158                 a[i,j]=d[k1][k2]
#
# KeyboardInterrupt:

# %%
##each entry is correlation between i and j
e_ij = nx.degree_mixing_matrix(G,x='out',y='in')
r = nx.degree_pearson_correlation_coefficient(G,x='out',y='in')
##visualize matrix
fig = plt.figure(figsize=(16,10))
plt.title(r"Degree Correlation Matrix of follow network (out-in), $r$="+str(r),fontsize=14)
plt.pcolormesh(e_ij, norm=LogNorm(vmax=e_ij.max()),cmap='plasma')
plt.colorbar()
plt.show()

# %%
##each entry is correlation between i and j
e_ij = nx.degree_mixing_matrix(G,x='out',y='out')
r = nx.degree_pearson_correlation_coefficient(G,x='out',y='out')
##visualize matrix
fig = plt.figure(figsize=(16,10))
plt.title(r"Degree Correlation Matrix of follow network (out-out), $r$="+str(r),fontsize=14)
plt.pcolormesh(e_ij, norm=LogNorm(vmax=e_ij.max()),cmap='plasma')
plt.colorbar()
plt.show()
